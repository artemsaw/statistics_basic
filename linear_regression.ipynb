# %%
import matplotlib.pyplot as plt
import random
from scipy.stats import linregress

# Число точек
N = 20
# Linkage factor [0, 1]
F = 0.5
random.seed()
X = [random.uniform(0, 1) for i in range (N)]
Y = [F * X[i] + (1 - F) * random.uniform(0, 1) for i  in range (N)]
lr = linregress(X, Y)
Yregr = [X[i] * lr.slope + lr.intercept for i in range(N)]
figure_title = 'r = {0}. p = {1}'.format(lr.rvalue, lr.pvalue)
plt.scatter(X, Y)
plt.title(figure_title)
plt.plot(X, Yregr, color='red')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_stats= pd.read_csv('http://d396qusza40orc.cloudfront.net/statistics/lec_resources/states.csv')

plot = df_stats.plot(x='hs_grad', y='poverty', kind='scatter', figsize=(18,5))
plt.title('Корреляция', fontsize=14)
plt.xlabel("Уровень образования %")
plt.ylabel("Уровень бедности %")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

 
dt = pd.read_csv('http://d396qusza40orc.cloudfront.net/statistics/lec_resources/states.csv')

plt.scatter(dt['hs_grad'], dt['poverty'])

plt.xlabel('Среднее образование (%)')

plt.ylabel('Бедность (%)')

b1, b0 = np.polyfit(dt['hs_grad'], dt['poverty'], 1)

plt.plot(dt['hs_grad'], b0 + b1*dt['hs_grad'], color='red')

dt1 = dt[['hs_grad', 'poverty']]

plt.show()
print(dt1.describe())
# Out:
#          hs_grad    poverty
# count  51.000000  51.000000
# mean   86.011765  11.349020
# std     3.725998   3.099185
# min    77.200000   5.600000
# 25%    83.300000   9.250000
# 50%    86.900000  10.600000
# 75%    88.700000  13.400000
# max    92.100000  18.000000
